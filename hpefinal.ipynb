# %% [markdown]
# <a href="https://colab.research.google.com/github/18BIS036/hpefinal/blob/main/hpefinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)

import cv2
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from PIL import Image
import math
import numpy as np
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
directory='/content/forms'
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
def image_binarization(image):
  # converting image to grayscale
  image_grayscale=image.convert('L')
  img=np.array(image_grayscale) 
   
  img[img <128] = 0
  img[img >=128] = 254 

  #making white as foreground pixels and black as background pixels
  img[img==0]=255
  img[img==254]=0
  
  return img


def line_segmentation(img):
  start_matrix=[]
  end_matrix=[]

  #matrix to get the start and end points of a line
  
  lines=[]
  begin_matrix=[]
  stop_matrix=[]
  del_start_matrix=[]
  del_end_matrix=[]

  horizontal_hist = np.sum(img,axis=1,keepdims=True)/255
  start_count=0

  for i in range(len(horizontal_hist)):

    if horizontal_hist[i]>0 and horizontal_hist[i-1]==0:
      start_count+=1
      start_matrix.append(i)

    if horizontal_hist[i]==0 and start_count>0 and horizontal_hist[i-1]>0:
      end_matrix.append(i)

  
  
  if len(start_matrix)==len(end_matrix):
    for i in range(len(start_matrix)):
      if end_matrix[i]-start_matrix[i]<20:
        del_start_matrix.append(i)
        del_end_matrix.append(i)
    for i in range(len(start_matrix)):
      count=0
      for j in range(len(del_start_matrix)):
        if i==del_start_matrix[j]:
          count=count+1
      if count==0:
        begin_matrix.append(start_matrix[i])
    for i in range(len(end_matrix)):
      count=0
      for j in range(len(del_end_matrix)):
        if i==del_end_matrix[j]:
          count=count+1
      if count==0:
        stop_matrix.append(end_matrix[i])
    
    for i in range(len(begin_matrix)):
      lines.append(img[begin_matrix[i]:stop_matrix[i],:])

      

      

  
  return lines




def word_segmentation(img):
  start_matrix=[]
  end_matrix=[]

  #matrix to get the start and end points of a word
  dissection_matrix=[]
  
  words=[]
  m,n=img.shape
  
  length=[]
  vertical_hist = np.sum(img,axis=0,keepdims=True)/255
  
  
  start_count=0
  
  
  for i in range(len(vertical_hist[0])):
    if vertical_hist[0][i]>0 and vertical_hist[0][i-1]==0:
      start_count+=1
      start_matrix.append(i)
    if vertical_hist[0][i]==0 and start_count>0 and vertical_hist[0][i-1]>0:
      end_matrix.append(i)
  
  
  length_mag=0
  for i in range(len(start_matrix)):
    if i>0:
      length_mag=(start_matrix[i]-end_matrix[i-1])
      length.append(length_mag)

  max=np.max(length)
     
  avg=max/3

  dissection_matrix.append([start_matrix[0],end_matrix[0]])
  j=0
  for i in range(len(length)-1):
    
    if length[i]> avg:
      dissection_matrix.append([start_matrix[i+1],end_matrix[i+1]])
      j=j+1
      
    if length[i]<=avg:
      dissection_matrix[j][1]=end_matrix[i+1]
  for i in range(len(dissection_matrix)):
    words.append(img[0:m,dissection_matrix[i][0]:dissection_matrix[i][1]])
  
  return words


def char_segmentation(img):
  start_matrix=[]
  dissection_matrix=[]
  delete_matrix=[]
  address_matrix=[]
  
  
  characters=[]
  m,n=img.shape

  vertical_hist = np.sum(img,axis=0,keepdims=True)/255
  start_matrix.append(0)

  for i in range(len(vertical_hist[0])):
    if vertical_hist[0][i]<10:
      start_matrix.append(i)

  for i in range(len(start_matrix)-1):
    if start_matrix[i+1]-start_matrix[i]<10:
      delete_matrix.append(i)
  
  for i in range(len(start_matrix)):
    count=0
    for j in range(len(delete_matrix)):
      if  i==delete_matrix[j]:
        count=count+1
    if count==0:
      address_matrix.append(start_matrix[i])


  for i in range(len(address_matrix)-1):
    dissection_matrix.append([address_matrix[i],address_matrix[i+1]])
  for i in range(len(dissection_matrix)):
    characters.append(img[0:m,dissection_matrix[i][0]:dissection_matrix[i][1]])
    
    
  return characters

# %%
def data_label():

  samples=[]
  labels=[]

 
  
 
  
  for filename in os.listdir(directory):
    count=0
    text=open('/content/lines_new.txt')
    image_orig=Image.open('/content/forms/'+filename,'r')
    img=image_binarization(image_orig)
    lines=line_segmentation(img)
    for line in text:
      line_Split = line.strip().split(" ")
      filename_split=filename.split('.')
      linesplit=line_Split[0].split("-")
      string= linesplit[0]+'-'+linesplit[1]
      if string==filename_split[0]:
          count=count+1
    if count==len(lines): 
      for i in range(len(lines)):
        try:
          words=word_segmentation(lines[i])
          text=open('/content/lines_new.txt')
          for line in text:
            lineSplit = line.strip().split(' ')
            filename_split=filename.split('.')
            if lineSplit[0]==filename_split[0]+'-'+str(0)+str(i):
              word_split = lineSplit[8].split('|')
              if len(word_split)==len(words):
                for j in range(len(words)):
                  characters=char_segmentation(words[j])
                  if len(word_split[j])==len(characters):
                    for k in range(len(characters)):
                      
                      character=cv2.resize(characters[k],(28,28))
                      samples.append(character)
                    for l in word_split[j]:
                      labels.append(l) 

        except ValueError as ve:
          continue  
  
                 
  
  return  samples,labels

samples,labels=data_label()
print(len(samples))
print(len(labels))
for i in range(5):
  print(labels[i])
# Out:
# 224
# 224
# a
# n
# d
# M
# r

# %%
samples = np.array(samples, dtype='float' )/ 255.0
labels = np.array(labels)
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels
samples.shape
# Out:
# (224, 28, 28)

# %%
from sklearn.model_selection import train_test_split
trainx,testx,trainy,testy = train_test_split(samples, labels, test_size=0.2, random_state=42)

# %%
len(testx)
testx.shape
trainx=trainx.reshape(trainx.shape[0],28,28,1)
testx=testx.reshape(testx.shape[0],28,28,1)

# %%
HP_epoch = 1000
HP_init_lr = 1e-3 # learning_rate = 0.001
HP_batch_size = 32
HP_image_dims = (28,28,1)
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
HP_model_path = 'bin/model'
HP_binarized_labels = 'bin/labels'
HP_metrics_storage = 'eval'

# %%
aug = ImageDataGenerator( rotation_range=25, width_shift_range=0.1, 
                         height_shift_range=0.1, shear_range=0.2,
                         zoom_range=0.2, horizontal_flip=True,fill_mode='nearest')

# %%
from keras import backend
from keras.layers.core import Dense, Dropout, Flatten, Activation
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
#N= 5
HP_block1_conv_dim = 32
HP_block2_conv_dim = 64
HP_block3_conv_dim = 128
HP_block4_conv_dim = 256
HP_block5_dense_dim = 1024
HP_small_pattern = (3,3) # UNCOMPRESSED or 1-2 compression IMAGES
HP_large_pattern = (2,2) # 4 times compressed images from previous MP layers!!!
HP_dropout_little =0.25
HP_dropout_big = 0.50
# HP_epochs, batch_size-> are now problems of the developer USING this model. 

HP_img_dims = (28,28,1)

# %%
class RacoonVGG:
  @staticmethod
  def build(height, width,depth, classes):
    input_shape = (height, width, depth)
    channel_dim = -1 # last position 
    if backend.image_data_format() == 'channels_first':
      input_shape = (depth, height, width)
      channel_dim = 1
    model = Sequential()
    # BLOCK1
    model.add(Conv2D(HP_block1_conv_dim,HP_small_pattern, padding='same',
                     input_shape=input_shape))
    model.add(Activation('relu'))
    model.add(BatchNormalization(axis=channel_dim))
    model.add(MaxPooling2D(pool_size=HP_small_pattern))
    model.add(Dropout(HP_dropout_little))

    # COMPLEX BLOCK 2
    model.add(Conv2D(HP_block2_conv_dim,HP_small_pattern, padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization(axis=channel_dim))
    model.add(Conv2D(HP_block2_conv_dim,HP_small_pattern, padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization(axis=channel_dim))
    model.add(MaxPooling2D(pool_size=HP_large_pattern))
    model.add(Dropout(HP_dropout_little))
    
    # COMPLEX BLOCK 3
    model.add(Conv2D(HP_block3_conv_dim,HP_small_pattern, padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization(axis=channel_dim))
    model.add(Conv2D(HP_block3_conv_dim,HP_small_pattern, padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization(axis=channel_dim))
    model.add(MaxPooling2D(pool_size=HP_large_pattern))
    model.add(Dropout(HP_dropout_little))

    # COMPLEX BLOCK 4
    model.add(Conv2D(HP_block4_conv_dim,HP_small_pattern, padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization(axis=channel_dim))
    model.add(Conv2D(HP_block4_conv_dim,HP_small_pattern, padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization(axis=channel_dim))
    model.add(MaxPooling2D(pool_size=HP_large_pattern))
    model.add(Dropout(HP_dropout_little))

    # BLOCK 5- Image Classification (OBJECT)
    model.add(Flatten())
    model.add(Dense(HP_block5_dense_dim))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(HP_dropout_big))
    model.add(Dense(classes))
    model.add(Activation('softmax'))
    return model


trainx=trainx.reshape(trainx.shape[0],28,28,1)
testx=testx.reshape(testx.shape[0],28,28,1)

# %%
import keras
import keras.utils
from keras import utils as np_utils
from keras.optimizers import adam
model = RacoonVGG.build(height=HP_img_dims[0], width=HP_img_dims[1],depth=HP_img_dims[2],classes = len(lb.classes_))
opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
hist = model.fit(aug.flow(trainx, trainy, batch_size=HP_batch_size),
                 validation_data=(testx, testy),
                 steps_per_epoch= len(trainx) // HP_batch_size,
                 epochs=HP_epoch, verbose=1)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/1000
# 5/5 [==============================] - 3s 515ms/step - loss: 5.1292 - accuracy: 0.0272 - val_loss: 3.3561 - val_accuracy: 0.0444
# Epoch 2/1000
# 5/5 [==============================] - 1s 191ms/step - loss: 4.5905 - accuracy: 0.0476 - val_loss: 3.3371 - val_accuracy: 0.0444
# Epoch 3/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 4.5816 - accuracy: 0.0884 - val_loss: 3.3225 - val_accuracy: 0.0444
# Epoch 4/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 4.2644 - accuracy: 0.0875 - val_loss: 3.3084 - val_accuracy: 0.0444
# Epoch 5/1000
# 5/5 [==============================] - 1s 188ms/step - loss: 4.2809 - accuracy: 0.0952 - val_loss: 3.3007 - val_accuracy: 0.0444
# Epoch 6/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 4.1948 - accuracy: 0.0748 - val_loss: 3.2949 - val_accuracy: 0.0444
# Epoch 7/1000
# 5/5 [==============================] - 1s 182ms/step - loss: 3.7889 - accuracy: 0.1361 - val_loss: 3.3090 - val_accuracy: 0.0444
# Epoch 8/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 3.7915 - accuracy: 0.1361 - val_loss: 3.3354 - val_accuracy: 0.0444
# Epoch 9/1000
# 5/5 [==============================] - 1s 208ms/step - loss: 3.7337 - accuracy: 0.1500 - val_loss: 3.3516 - val_accuracy: 0.0444
# Epoch 10/1000
# 5/5 [==============================] - 1s 178ms/step - loss: 3.9729 - accuracy: 0.1716 - val_loss: 3.3610 - val_accuracy: 0.0444
# Epoch 11/1000
# 5/5 [==============================] - 1s 205ms/step - loss: 3.9003 - accuracy: 0.1250 - val_loss: 3.3473 - val_accuracy: 0.0444
# Epoch 12/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 3.7054 - accuracy: 0.1020 - val_loss: 3.3312 - val_accuracy: 0.0444
# Epoch 13/1000
# 5/5 [==============================] - 1s 181ms/step - loss: 3.6315 - accuracy: 0.1701 - val_loss: 3.3263 - val_accuracy: 0.0444
# Epoch 14/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 3.7084 - accuracy: 0.1361 - val_loss: 3.3628 - val_accuracy: 0.0667
# Epoch 15/1000
# 5/5 [==============================] - 1s 200ms/step - loss: 3.4558 - accuracy: 0.1625 - val_loss: 3.3921 - val_accuracy: 0.0889
# Epoch 16/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 3.5392 - accuracy: 0.1769 - val_loss: 3.3755 - val_accuracy: 0.0889
# Epoch 17/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 3.6011 - accuracy: 0.1769 - val_loss: 3.3856 - val_accuracy: 0.0889
# Epoch 18/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 3.4687 - accuracy: 0.1361 - val_loss: 3.3902 - val_accuracy: 0.0222
# Epoch 19/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 3.3783 - accuracy: 0.1813 - val_loss: 3.5146 - val_accuracy: 0.0444
# Epoch 20/1000
# 5/5 [==============================] - 1s 176ms/step - loss: 3.3837 - accuracy: 0.2090 - val_loss: 3.4941 - val_accuracy: 0.0222
# Epoch 21/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 3.2695 - accuracy: 0.1565 - val_loss: 3.4835 - val_accuracy: 0.0222
# Epoch 22/1000
# 5/5 [==============================] - 1s 204ms/step - loss: 3.2974 - accuracy: 0.1937 - val_loss: 3.4707 - val_accuracy: 0.0222
# Epoch 23/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 3.2339 - accuracy: 0.1565 - val_loss: 3.4656 - val_accuracy: 0.0444
# Epoch 24/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 3.1328 - accuracy: 0.1837 - val_loss: 3.5084 - val_accuracy: 0.0667
# Epoch 25/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 3.0515 - accuracy: 0.1625 - val_loss: 3.5535 - val_accuracy: 0.0444
# Epoch 26/1000
# 5/5 [==============================] - 1s 178ms/step - loss: 3.1735 - accuracy: 0.1716 - val_loss: 3.5677 - val_accuracy: 0.0444
# Epoch 27/1000
# 5/5 [==============================] - 1s 204ms/step - loss: 3.1904 - accuracy: 0.1813 - val_loss: 3.5667 - val_accuracy: 0.0667
# Epoch 28/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 2.9761 - accuracy: 0.2313 - val_loss: 3.7825 - val_accuracy: 0.0444
# Epoch 29/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 3.2131 - accuracy: 0.1633 - val_loss: 3.9465 - val_accuracy: 0.0222
# Epoch 30/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 2.7062 - accuracy: 0.2993 - val_loss: 3.8862 - val_accuracy: 0.0222
# Epoch 31/1000
# 5/5 [==============================] - 1s 184ms/step - loss: 3.0115 - accuracy: 0.2449 - val_loss: 3.8688 - val_accuracy: 0.0222
# Epoch 32/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 3.1905 - accuracy: 0.1905 - val_loss: 3.7993 - val_accuracy: 0.0222
# Epoch 33/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 3.2177 - accuracy: 0.2381 - val_loss: 3.8272 - val_accuracy: 0.0444
# Epoch 34/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 3.1471 - accuracy: 0.2177 - val_loss: 3.8056 - val_accuracy: 0.0889
# Epoch 35/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 2.9686 - accuracy: 0.1905 - val_loss: 3.7884 - val_accuracy: 0.0444
# Epoch 36/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 2.8485 - accuracy: 0.2062 - val_loss: 3.7776 - val_accuracy: 0.0222
# Epoch 37/1000
# 5/5 [==============================] - 1s 187ms/step - loss: 2.9792 - accuracy: 0.1701 - val_loss: 3.7657 - val_accuracy: 0.0222
# Epoch 38/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 2.8453 - accuracy: 0.2517 - val_loss: 3.6999 - val_accuracy: 0.0444
# Epoch 39/1000
# 5/5 [==============================] - 1s 201ms/step - loss: 3.0855 - accuracy: 0.1701 - val_loss: 3.7044 - val_accuracy: 0.0222
# Epoch 40/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 2.7971 - accuracy: 0.2250 - val_loss: 3.7734 - val_accuracy: 0.0222
# Epoch 41/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 2.9287 - accuracy: 0.1701 - val_loss: 3.8400 - val_accuracy: 0.0222
# Epoch 42/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 2.8169 - accuracy: 0.2381 - val_loss: 3.8839 - val_accuracy: 0.0444
# Epoch 43/1000
# 5/5 [==============================] - 1s 182ms/step - loss: 2.8635 - accuracy: 0.2177 - val_loss: 3.9700 - val_accuracy: 0.0222
# Epoch 44/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 2.7237 - accuracy: 0.2313 - val_loss: 3.9678 - val_accuracy: 0.0444
# Epoch 45/1000
# 5/5 [==============================] - 1s 191ms/step - loss: 2.5654 - accuracy: 0.2993 - val_loss: 3.9343 - val_accuracy: 0.0000e+00
# Epoch 46/1000
# 5/5 [==============================] - 1s 203ms/step - loss: 2.7504 - accuracy: 0.2375 - val_loss: 3.8987 - val_accuracy: 0.0000e+00
# Epoch 47/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 2.6918 - accuracy: 0.2653 - val_loss: 3.9738 - val_accuracy: 0.0000e+00
# Epoch 48/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 2.8489 - accuracy: 0.1837 - val_loss: 4.0167 - val_accuracy: 0.0000e+00
# Epoch 49/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 2.5173 - accuracy: 0.2721 - val_loss: 4.0176 - val_accuracy: 0.0000e+00
# Epoch 50/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 2.6802 - accuracy: 0.2177 - val_loss: 4.0359 - val_accuracy: 0.0000e+00
# Epoch 51/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 3.1323 - accuracy: 0.1837 - val_loss: 4.1908 - val_accuracy: 0.0000e+00
# Epoch 52/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 2.5409 - accuracy: 0.2250 - val_loss: 4.4949 - val_accuracy: 0.0000e+00
# Epoch 53/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 2.5893 - accuracy: 0.2517 - val_loss: 4.6218 - val_accuracy: 0.0000e+00
# Epoch 54/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 2.7307 - accuracy: 0.3061 - val_loss: 4.6513 - val_accuracy: 0.0000e+00
# Epoch 55/1000
# 5/5 [==============================] - 1s 182ms/step - loss: 2.5277 - accuracy: 0.2789 - val_loss: 4.6101 - val_accuracy: 0.0000e+00
# Epoch 56/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 2.6788 - accuracy: 0.2245 - val_loss: 4.3394 - val_accuracy: 0.0000e+00
# Epoch 57/1000
# 5/5 [==============================] - 1s 205ms/step - loss: 2.4669 - accuracy: 0.2500 - val_loss: 4.1103 - val_accuracy: 0.0000e+00
# Epoch 58/1000
# 5/5 [==============================] - 1s 179ms/step - loss: 2.4126 - accuracy: 0.2761 - val_loss: 4.1244 - val_accuracy: 0.0222
# Epoch 59/1000
# 5/5 [==============================] - 1s 208ms/step - loss: 2.5532 - accuracy: 0.2750 - val_loss: 4.1020 - val_accuracy: 0.0444
# Epoch 60/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 2.4304 - accuracy: 0.2925 - val_loss: 3.9873 - val_accuracy: 0.0667
# Epoch 61/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 2.5525 - accuracy: 0.2375 - val_loss: 4.0116 - val_accuracy: 0.0444
# Epoch 62/1000
# 5/5 [==============================] - 1s 180ms/step - loss: 2.3646 - accuracy: 0.2687 - val_loss: 4.0475 - val_accuracy: 0.0444
# Epoch 63/1000
# 5/5 [==============================] - 1s 201ms/step - loss: 2.4700 - accuracy: 0.2937 - val_loss: 4.1722 - val_accuracy: 0.0222
# Epoch 64/1000
# 5/5 [==============================] - 1s 183ms/step - loss: 2.3029 - accuracy: 0.3657 - val_loss: 4.2799 - val_accuracy: 0.0222
# Epoch 65/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 2.4039 - accuracy: 0.2625 - val_loss: 4.2612 - val_accuracy: 0.0222
# Epoch 66/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 2.5781 - accuracy: 0.2109 - val_loss: 4.1154 - val_accuracy: 0.0222
# Epoch 67/1000
# 5/5 [==============================] - 1s 185ms/step - loss: 2.2936 - accuracy: 0.2789 - val_loss: 4.0474 - val_accuracy: 0.0000e+00
# Epoch 68/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 2.4364 - accuracy: 0.2313 - val_loss: 4.1598 - val_accuracy: 0.0000e+00
# Epoch 69/1000
# 5/5 [==============================] - 1s 182ms/step - loss: 2.3917 - accuracy: 0.2836 - val_loss: 4.4152 - val_accuracy: 0.0000e+00
# Epoch 70/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 2.3905 - accuracy: 0.3438 - val_loss: 4.4204 - val_accuracy: 0.0000e+00
# Epoch 71/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 2.3469 - accuracy: 0.3129 - val_loss: 4.1545 - val_accuracy: 0.0222
# Epoch 72/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 2.3394 - accuracy: 0.3401 - val_loss: 3.9860 - val_accuracy: 0.0222
# Epoch 73/1000
# 5/5 [==============================] - 1s 186ms/step - loss: 2.5255 - accuracy: 0.2789 - val_loss: 3.9522 - val_accuracy: 0.0444
# Epoch 74/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 2.2732 - accuracy: 0.2721 - val_loss: 4.0310 - val_accuracy: 0.0444
# Epoch 75/1000
# 5/5 [==============================] - 1s 208ms/step - loss: 2.4452 - accuracy: 0.2875 - val_loss: 3.8835 - val_accuracy: 0.0667
# Epoch 76/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 2.4332 - accuracy: 0.3061 - val_loss: 3.5823 - val_accuracy: 0.0444
# Epoch 77/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 2.5225 - accuracy: 0.2653 - val_loss: 3.4177 - val_accuracy: 0.0222
# Epoch 78/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 2.1920 - accuracy: 0.2993 - val_loss: 3.4504 - val_accuracy: 0.0222
# Epoch 79/1000
# 5/5 [==============================] - 1s 188ms/step - loss: 2.3633 - accuracy: 0.2381 - val_loss: 3.4005 - val_accuracy: 0.0444
# Epoch 80/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 2.2616 - accuracy: 0.3129 - val_loss: 3.5190 - val_accuracy: 0.0889
# Epoch 81/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 2.4626 - accuracy: 0.2585 - val_loss: 3.6383 - val_accuracy: 0.0222
# Epoch 82/1000
# 5/5 [==============================] - 1s 205ms/step - loss: 2.5854 - accuracy: 0.2562 - val_loss: 3.7087 - val_accuracy: 0.0222
# Epoch 83/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 2.2863 - accuracy: 0.3333 - val_loss: 3.7930 - val_accuracy: 0.0222
# Epoch 84/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 2.3407 - accuracy: 0.3129 - val_loss: 3.7349 - val_accuracy: 0.0444
# Epoch 85/1000
# 5/5 [==============================] - 1s 182ms/step - loss: 2.1668 - accuracy: 0.3946 - val_loss: 3.6626 - val_accuracy: 0.0889
# Epoch 86/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 2.3688 - accuracy: 0.3333 - val_loss: 3.6168 - val_accuracy: 0.0444
# Epoch 87/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 2.3630 - accuracy: 0.2585 - val_loss: 3.6333 - val_accuracy: 0.0667
# Epoch 88/1000
# 5/5 [==============================] - 1s 203ms/step - loss: 2.1840 - accuracy: 0.2937 - val_loss: 3.6151 - val_accuracy: 0.1111
# Epoch 89/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 2.3990 - accuracy: 0.2857 - val_loss: 3.5345 - val_accuracy: 0.1556
# Epoch 90/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 2.4558 - accuracy: 0.3129 - val_loss: 3.4235 - val_accuracy: 0.1556
# Epoch 91/1000
# 5/5 [==============================] - 1s 186ms/step - loss: 2.4899 - accuracy: 0.2857 - val_loss: 3.3370 - val_accuracy: 0.1333
# Epoch 92/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 2.1588 - accuracy: 0.3537 - val_loss: 3.3790 - val_accuracy: 0.1111
# Epoch 93/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 2.4578 - accuracy: 0.3061 - val_loss: 3.4858 - val_accuracy: 0.0889
# Epoch 94/1000
# 5/5 [==============================] - 1s 206ms/step - loss: 2.5237 - accuracy: 0.2812 - val_loss: 3.5217 - val_accuracy: 0.1111
# Epoch 95/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 2.4001 - accuracy: 0.2857 - val_loss: 3.4523 - val_accuracy: 0.1111
# Epoch 96/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 2.3166 - accuracy: 0.2993 - val_loss: 3.5707 - val_accuracy: 0.1778
# Epoch 97/1000
# 5/5 [==============================] - 1s 189ms/step - loss: 2.1763 - accuracy: 0.3265 - val_loss: 3.4272 - val_accuracy: 0.1333
# Epoch 98/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 2.0506 - accuracy: 0.3061 - val_loss: 3.3779 - val_accuracy: 0.0667
# Epoch 99/1000
# 5/5 [==============================] - 1s 215ms/step - loss: 2.1917 - accuracy: 0.2937 - val_loss: 3.5812 - val_accuracy: 0.1111
# Epoch 100/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.8983 - accuracy: 0.4014 - val_loss: 3.6664 - val_accuracy: 0.0889
# Epoch 101/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 2.3637 - accuracy: 0.3507 - val_loss: 3.5804 - val_accuracy: 0.1333
# Epoch 102/1000
# 5/5 [==============================] - 1s 217ms/step - loss: 2.2497 - accuracy: 0.3500 - val_loss: 3.5051 - val_accuracy: 0.1333
# Epoch 103/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 2.1118 - accuracy: 0.3673 - val_loss: 3.4584 - val_accuracy: 0.1111
# Epoch 104/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 2.1315 - accuracy: 0.4014 - val_loss: 3.5280 - val_accuracy: 0.1333
# Epoch 105/1000
# 5/5 [==============================] - 1s 216ms/step - loss: 2.0608 - accuracy: 0.3313 - val_loss: 3.4397 - val_accuracy: 0.1556
# Epoch 106/1000
# 5/5 [==============================] - 1s 188ms/step - loss: 2.0417 - accuracy: 0.3284 - val_loss: 3.3136 - val_accuracy: 0.1556
# Epoch 107/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 2.0722 - accuracy: 0.3750 - val_loss: 3.2056 - val_accuracy: 0.2222
# Epoch 108/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 2.0974 - accuracy: 0.3537 - val_loss: 3.2143 - val_accuracy: 0.1333
# Epoch 109/1000
# 5/5 [==============================] - 1s 183ms/step - loss: 2.1538 - accuracy: 0.3401 - val_loss: 3.3895 - val_accuracy: 0.0889
# Epoch 110/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 2.0609 - accuracy: 0.3537 - val_loss: 3.3974 - val_accuracy: 0.1111
# Epoch 111/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 2.0942 - accuracy: 0.3673 - val_loss: 3.3273 - val_accuracy: 0.1333
# Epoch 112/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 1.8412 - accuracy: 0.3946 - val_loss: 3.3136 - val_accuracy: 0.1556
# Epoch 113/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 2.1250 - accuracy: 0.3375 - val_loss: 3.3466 - val_accuracy: 0.1556
# Epoch 114/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 1.9679 - accuracy: 0.3741 - val_loss: 3.3446 - val_accuracy: 0.1556
# Epoch 115/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 1.9272 - accuracy: 0.3469 - val_loss: 3.1888 - val_accuracy: 0.2000
# Epoch 116/1000
# 5/5 [==============================] - 1s 213ms/step - loss: 2.1083 - accuracy: 0.3875 - val_loss: 2.9906 - val_accuracy: 0.2444
# Epoch 117/1000
# 5/5 [==============================] - 1s 191ms/step - loss: 1.9819 - accuracy: 0.3810 - val_loss: 2.9337 - val_accuracy: 0.2889
# Epoch 118/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 2.0379 - accuracy: 0.3946 - val_loss: 2.9816 - val_accuracy: 0.3111
# Epoch 119/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 1.9894 - accuracy: 0.3673 - val_loss: 3.0706 - val_accuracy: 0.2667
# Epoch 120/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.8429 - accuracy: 0.3810 - val_loss: 3.1603 - val_accuracy: 0.2667
# Epoch 121/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 2.0051 - accuracy: 0.3812 - val_loss: 3.2012 - val_accuracy: 0.2444
# Epoch 122/1000
# 5/5 [==============================] - 1s 182ms/step - loss: 1.8489 - accuracy: 0.3806 - val_loss: 3.1283 - val_accuracy: 0.3111
# Epoch 123/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 2.0033 - accuracy: 0.3333 - val_loss: 3.0630 - val_accuracy: 0.3333
# Epoch 124/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 2.1811 - accuracy: 0.3625 - val_loss: 3.1395 - val_accuracy: 0.3111
# Epoch 125/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 2.0762 - accuracy: 0.3605 - val_loss: 3.1682 - val_accuracy: 0.2667
# Epoch 126/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 2.2047 - accuracy: 0.3333 - val_loss: 3.1492 - val_accuracy: 0.2889
# Epoch 127/1000
# 5/5 [==============================] - 1s 189ms/step - loss: 1.9203 - accuracy: 0.3878 - val_loss: 3.1210 - val_accuracy: 0.2444
# Epoch 128/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 1.8751 - accuracy: 0.4762 - val_loss: 3.1161 - val_accuracy: 0.2222
# Epoch 129/1000
# 5/5 [==============================] - 1s 206ms/step - loss: 2.0273 - accuracy: 0.3750 - val_loss: 3.1106 - val_accuracy: 0.2889
# Epoch 130/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 1.9546 - accuracy: 0.4150 - val_loss: 2.9762 - val_accuracy: 0.3111
# Epoch 131/1000
# 5/5 [==============================] - 1s 182ms/step - loss: 1.8330 - accuracy: 0.3582 - val_loss: 2.9835 - val_accuracy: 0.3111
# Epoch 132/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 1.9123 - accuracy: 0.3812 - val_loss: 3.0138 - val_accuracy: 0.3333
# Epoch 133/1000
# 5/5 [==============================] - 1s 184ms/step - loss: 1.8446 - accuracy: 0.3810 - val_loss: 3.0561 - val_accuracy: 0.2889
# Epoch 134/1000
# 5/5 [==============================] - 1s 200ms/step - loss: 1.8138 - accuracy: 0.4762 - val_loss: 3.0778 - val_accuracy: 0.2889
# Epoch 135/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 1.8217 - accuracy: 0.4062 - val_loss: 3.0885 - val_accuracy: 0.2889
# Epoch 136/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 1.8760 - accuracy: 0.3946 - val_loss: 3.0745 - val_accuracy: 0.2889
# Epoch 137/1000
# 5/5 [==============================] - 1s 185ms/step - loss: 2.1470 - accuracy: 0.3806 - val_loss: 3.0586 - val_accuracy: 0.2667
# Epoch 138/1000
# 5/5 [==============================] - 1s 204ms/step - loss: 1.8452 - accuracy: 0.4125 - val_loss: 3.0611 - val_accuracy: 0.2667
# Epoch 139/1000
# 5/5 [==============================] - 1s 186ms/step - loss: 1.7067 - accuracy: 0.4558 - val_loss: 3.0378 - val_accuracy: 0.3111
# Epoch 140/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 1.8769 - accuracy: 0.3810 - val_loss: 3.0863 - val_accuracy: 0.3111
# Epoch 141/1000
# 5/5 [==============================] - 1s 206ms/step - loss: 2.0955 - accuracy: 0.3688 - val_loss: 2.9836 - val_accuracy: 0.3111
# Epoch 142/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 1.7244 - accuracy: 0.4218 - val_loss: 2.8511 - val_accuracy: 0.3778
# Epoch 143/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 1.9927 - accuracy: 0.3605 - val_loss: 2.8738 - val_accuracy: 0.3556
# Epoch 144/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 1.8433 - accuracy: 0.4354 - val_loss: 2.9386 - val_accuracy: 0.3778
# Epoch 145/1000
# 5/5 [==============================] - 1s 184ms/step - loss: 1.7637 - accuracy: 0.4830 - val_loss: 2.9820 - val_accuracy: 0.3556
# Epoch 146/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 1.8211 - accuracy: 0.4750 - val_loss: 3.0707 - val_accuracy: 0.4000
# Epoch 147/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 1.9225 - accuracy: 0.3673 - val_loss: 3.2720 - val_accuracy: 0.3111
# Epoch 148/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 1.6983 - accuracy: 0.5034 - val_loss: 3.3900 - val_accuracy: 0.3333
# Epoch 149/1000
# 5/5 [==============================] - 1s 191ms/step - loss: 1.7629 - accuracy: 0.4354 - val_loss: 3.4197 - val_accuracy: 0.3333
# Epoch 150/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 1.8225 - accuracy: 0.4150 - val_loss: 3.3522 - val_accuracy: 0.3111
# Epoch 151/1000
# 5/5 [==============================] - 1s 183ms/step - loss: 1.9411 - accuracy: 0.4218 - val_loss: 3.2981 - val_accuracy: 0.3556
# Epoch 152/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 1.7802 - accuracy: 0.4150 - val_loss: 3.3057 - val_accuracy: 0.3778
# Epoch 153/1000
# 5/5 [==============================] - 1s 208ms/step - loss: 1.8495 - accuracy: 0.4062 - val_loss: 3.3216 - val_accuracy: 0.3111
# Epoch 154/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 1.7792 - accuracy: 0.4082 - val_loss: 3.3601 - val_accuracy: 0.2444
# Epoch 155/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.5947 - accuracy: 0.5442 - val_loss: 3.3539 - val_accuracy: 0.2667
# Epoch 156/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 1.7799 - accuracy: 0.4626 - val_loss: 3.3268 - val_accuracy: 0.3333
# Epoch 157/1000
# 5/5 [==============================] - 1s 185ms/step - loss: 1.8355 - accuracy: 0.4218 - val_loss: 3.1827 - val_accuracy: 0.3333
# Epoch 158/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 1.8526 - accuracy: 0.3946 - val_loss: 3.1595 - val_accuracy: 0.3333
# Epoch 159/1000
# 5/5 [==============================] - 1s 203ms/step - loss: 1.7080 - accuracy: 0.4966 - val_loss: 3.1552 - val_accuracy: 0.3333
# Epoch 160/1000
# 5/5 [==============================] - 1s 203ms/step - loss: 1.9307 - accuracy: 0.4082 - val_loss: 3.2072 - val_accuracy: 0.3556
# Epoch 161/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 1.7017 - accuracy: 0.4187 - val_loss: 3.3808 - val_accuracy: 0.2889
# Epoch 162/1000
# 5/5 [==============================] - 1s 204ms/step - loss: 1.7985 - accuracy: 0.4626 - val_loss: 3.4692 - val_accuracy: 0.2667
# Epoch 163/1000
# 5/5 [==============================] - 1s 202ms/step - loss: 1.6369 - accuracy: 0.4812 - val_loss: 3.5954 - val_accuracy: 0.2444
# Epoch 164/1000
# 5/5 [==============================] - 1s 191ms/step - loss: 1.7130 - accuracy: 0.5149 - val_loss: 3.4658 - val_accuracy: 0.2667
# Epoch 165/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 1.6656 - accuracy: 0.4500 - val_loss: 3.3308 - val_accuracy: 0.2889
# Epoch 166/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 1.7540 - accuracy: 0.4286 - val_loss: 3.3266 - val_accuracy: 0.3333
# Epoch 167/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 1.8931 - accuracy: 0.4286 - val_loss: 3.3346 - val_accuracy: 0.3333
# Epoch 168/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 1.7013 - accuracy: 0.4830 - val_loss: 3.4191 - val_accuracy: 0.2444
# Epoch 169/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 1.7112 - accuracy: 0.4250 - val_loss: 3.4025 - val_accuracy: 0.2889
# Epoch 170/1000
# 5/5 [==============================] - 1s 179ms/step - loss: 1.8963 - accuracy: 0.3955 - val_loss: 3.3742 - val_accuracy: 0.3111
# Epoch 171/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 1.7813 - accuracy: 0.4014 - val_loss: 3.4229 - val_accuracy: 0.3111
# Epoch 172/1000
# 5/5 [==============================] - 1s 206ms/step - loss: 1.7538 - accuracy: 0.4250 - val_loss: 3.5236 - val_accuracy: 0.3333
# Epoch 173/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 1.6831 - accuracy: 0.4694 - val_loss: 3.8659 - val_accuracy: 0.2667
# Epoch 174/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 1.7264 - accuracy: 0.4422 - val_loss: 4.0821 - val_accuracy: 0.2222
# Epoch 175/1000
# 5/5 [==============================] - 1s 186ms/step - loss: 1.7213 - accuracy: 0.4558 - val_loss: 4.0308 - val_accuracy: 0.2222
# Epoch 176/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 1.8321 - accuracy: 0.4437 - val_loss: 3.9829 - val_accuracy: 0.2444
# Epoch 177/1000
# 5/5 [==============================] - 1s 183ms/step - loss: 1.4935 - accuracy: 0.5224 - val_loss: 4.1158 - val_accuracy: 0.1778
# Epoch 178/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 1.7228 - accuracy: 0.3946 - val_loss: 3.9680 - val_accuracy: 0.2222
# Epoch 179/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 1.5775 - accuracy: 0.4875 - val_loss: 3.8820 - val_accuracy: 0.2444
# Epoch 180/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 1.7854 - accuracy: 0.4082 - val_loss: 3.7025 - val_accuracy: 0.2889
# Epoch 181/1000
# 5/5 [==============================] - 1s 187ms/step - loss: 1.5023 - accuracy: 0.4966 - val_loss: 3.7270 - val_accuracy: 0.2667
# Epoch 182/1000
# 5/5 [==============================] - 1s 206ms/step - loss: 1.7275 - accuracy: 0.4625 - val_loss: 3.8366 - val_accuracy: 0.2889
# Epoch 183/1000
# 5/5 [==============================] - 1s 180ms/step - loss: 1.6792 - accuracy: 0.4030 - val_loss: 3.9984 - val_accuracy: 0.3111
# Epoch 184/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 1.6198 - accuracy: 0.4688 - val_loss: 3.9967 - val_accuracy: 0.3111
# Epoch 185/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 1.5950 - accuracy: 0.4694 - val_loss: 3.9384 - val_accuracy: 0.3333
# Epoch 186/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 1.5235 - accuracy: 0.4898 - val_loss: 3.8658 - val_accuracy: 0.2889
# Epoch 187/1000
# 5/5 [==============================] - 1s 187ms/step - loss: 1.6619 - accuracy: 0.4762 - val_loss: 3.9250 - val_accuracy: 0.2889
# Epoch 188/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.7242 - accuracy: 0.4694 - val_loss: 3.6358 - val_accuracy: 0.2667
# Epoch 189/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.7086 - accuracy: 0.4558 - val_loss: 3.4994 - val_accuracy: 0.2222
# Epoch 190/1000
# 5/5 [==============================] - 1s 204ms/step - loss: 1.5905 - accuracy: 0.4500 - val_loss: 3.5128 - val_accuracy: 0.2000
# Epoch 191/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 1.5254 - accuracy: 0.4558 - val_loss: 3.3954 - val_accuracy: 0.2222
# Epoch 192/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.4082 - accuracy: 0.5374 - val_loss: 3.3284 - val_accuracy: 0.2889
# Epoch 193/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.5390 - accuracy: 0.4688 - val_loss: 3.2072 - val_accuracy: 0.3333
# Epoch 194/1000
# 5/5 [==============================] - 1s 182ms/step - loss: 1.7000 - accuracy: 0.4851 - val_loss: 3.0849 - val_accuracy: 0.3778
# Epoch 195/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.5217 - accuracy: 0.5170 - val_loss: 3.1443 - val_accuracy: 0.3333
# Epoch 196/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.8330 - accuracy: 0.4286 - val_loss: 3.2388 - val_accuracy: 0.3333
# Epoch 197/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 1.4446 - accuracy: 0.5125 - val_loss: 3.3932 - val_accuracy: 0.3333
# Epoch 198/1000
# 5/5 [==============================] - 1s 192ms/step - loss: 1.4197 - accuracy: 0.5102 - val_loss: 3.4292 - val_accuracy: 0.2889
# Epoch 199/1000
# 5/5 [==============================] - 1s 183ms/step - loss: 1.8752 - accuracy: 0.3741 - val_loss: 3.4981 - val_accuracy: 0.2444
# Epoch 200/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 1.5677 - accuracy: 0.4626 - val_loss: 3.7276 - val_accuracy: 0.2667
# Epoch 201/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 1.5911 - accuracy: 0.5102 - val_loss: 3.9840 - val_accuracy: 0.2000
# Epoch 202/1000
# 5/5 [==============================] - 1s 205ms/step - loss: 1.6392 - accuracy: 0.4500 - val_loss: 4.1802 - val_accuracy: 0.2000
# Epoch 203/1000
# 5/5 [==============================] - 1s 182ms/step - loss: 1.4951 - accuracy: 0.4925 - val_loss: 4.0501 - val_accuracy: 0.2222
# Epoch 204/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 1.5119 - accuracy: 0.5125 - val_loss: 3.8043 - val_accuracy: 0.2222
# Epoch 205/1000
# 5/5 [==============================] - 1s 186ms/step - loss: 1.3027 - accuracy: 0.5510 - val_loss: 3.7835 - val_accuracy: 0.2444
# Epoch 206/1000
# 5/5 [==============================] - 1s 217ms/step - loss: 1.6100 - accuracy: 0.4500 - val_loss: 3.8300 - val_accuracy: 0.2444
# Epoch 207/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 1.8184 - accuracy: 0.4694 - val_loss: 3.9104 - val_accuracy: 0.2222
# Epoch 208/1000
# 5/5 [==============================] - 1s 203ms/step - loss: 1.4609 - accuracy: 0.4422 - val_loss: 3.7046 - val_accuracy: 0.2889
# Epoch 209/1000
# 5/5 [==============================] - 1s 200ms/step - loss: 1.5283 - accuracy: 0.4966 - val_loss: 3.5063 - val_accuracy: 0.2889
# Epoch 210/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 1.5495 - accuracy: 0.5102 - val_loss: 3.4511 - val_accuracy: 0.3333
# Epoch 211/1000
# 5/5 [==============================] - 1s 191ms/step - loss: 1.4819 - accuracy: 0.5306 - val_loss: 3.7771 - val_accuracy: 0.2444
# Epoch 212/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.5140 - accuracy: 0.4898 - val_loss: 4.3362 - val_accuracy: 0.1556
# Epoch 213/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 1.6911 - accuracy: 0.5000 - val_loss: 4.3889 - val_accuracy: 0.1778
# Epoch 214/1000
# 5/5 [==============================] - 1s 178ms/step - loss: 1.4499 - accuracy: 0.5522 - val_loss: 3.8496 - val_accuracy: 0.2444
# Epoch 215/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 1.4227 - accuracy: 0.5437 - val_loss: 3.9064 - val_accuracy: 0.2444
# Epoch 216/1000
# 5/5 [==============================] - 1s 189ms/step - loss: 1.6073 - accuracy: 0.4558 - val_loss: 4.1515 - val_accuracy: 0.2889
# Epoch 217/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 1.4095 - accuracy: 0.5306 - val_loss: 4.4013 - val_accuracy: 0.2667
# Epoch 218/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 1.5247 - accuracy: 0.5102 - val_loss: 4.5516 - val_accuracy: 0.2667
# Epoch 219/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 1.5474 - accuracy: 0.5188 - val_loss: 4.5608 - val_accuracy: 0.2222
# Epoch 220/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.5573 - accuracy: 0.5034 - val_loss: 4.1062 - val_accuracy: 0.2222
# Epoch 221/1000
# 5/5 [==============================] - 1s 188ms/step - loss: 1.5122 - accuracy: 0.5373 - val_loss: 3.9623 - val_accuracy: 0.2000
# Epoch 222/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 1.5415 - accuracy: 0.4812 - val_loss: 4.0214 - val_accuracy: 0.2222
# Epoch 223/1000
# 5/5 [==============================] - 1s 187ms/step - loss: 1.5031 - accuracy: 0.4898 - val_loss: 3.9660 - val_accuracy: 0.2222
# Epoch 224/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 1.3606 - accuracy: 0.5510 - val_loss: 3.9683 - val_accuracy: 0.3111
# Epoch 225/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 1.3339 - accuracy: 0.5312 - val_loss: 3.8867 - val_accuracy: 0.3778
# Epoch 226/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.4058 - accuracy: 0.5646 - val_loss: 3.8313 - val_accuracy: 0.3556
# Epoch 227/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 1.5729 - accuracy: 0.5374 - val_loss: 3.8354 - val_accuracy: 0.3111
# Epoch 228/1000
# 5/5 [==============================] - 1s 201ms/step - loss: 1.3692 - accuracy: 0.5374 - val_loss: 3.8669 - val_accuracy: 0.3333
# Epoch 229/1000
# 5/5 [==============================] - 1s 186ms/step - loss: 1.2844 - accuracy: 0.5238 - val_loss: 3.9197 - val_accuracy: 0.2667
# Epoch 230/1000
# 5/5 [==============================] - 1s 200ms/step - loss: 1.2905 - accuracy: 0.6122 - val_loss: 3.8424 - val_accuracy: 0.2889
# Epoch 231/1000
# 5/5 [==============================] - 1s 208ms/step - loss: 1.3425 - accuracy: 0.5750 - val_loss: 3.8125 - val_accuracy: 0.3556
# Epoch 232/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.3075 - accuracy: 0.5306 - val_loss: 4.0223 - val_accuracy: 0.3333
# Epoch 233/1000
# 5/5 [==============================] - 1s 184ms/step - loss: 1.3215 - accuracy: 0.5672 - val_loss: 4.1217 - val_accuracy: 0.2444
# Epoch 234/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 1.3998 - accuracy: 0.5063 - val_loss: 4.0734 - val_accuracy: 0.1778
# Epoch 235/1000
# 5/5 [==============================] - 1s 204ms/step - loss: 1.2406 - accuracy: 0.5750 - val_loss: 4.0340 - val_accuracy: 0.2222
# Epoch 236/1000
# 5/5 [==============================] - 1s 185ms/step - loss: 1.3219 - accuracy: 0.5373 - val_loss: 3.8728 - val_accuracy: 0.2667
# Epoch 237/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 1.3851 - accuracy: 0.5500 - val_loss: 3.8369 - val_accuracy: 0.3111
# Epoch 238/1000
# 5/5 [==============================] - 1s 185ms/step - loss: 1.1608 - accuracy: 0.6045 - val_loss: 4.0002 - val_accuracy: 0.2222
# Epoch 239/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 1.2748 - accuracy: 0.5750 - val_loss: 4.0580 - val_accuracy: 0.2667
# Epoch 240/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 1.1486 - accuracy: 0.6395 - val_loss: 4.0177 - val_accuracy: 0.3333
# Epoch 241/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 1.3327 - accuracy: 0.5714 - val_loss: 3.9776 - val_accuracy: 0.3111
# Epoch 242/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.3884 - accuracy: 0.5714 - val_loss: 4.4066 - val_accuracy: 0.2889
# Epoch 243/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 1.3009 - accuracy: 0.5375 - val_loss: 4.7058 - val_accuracy: 0.1778
# Epoch 244/1000
# 5/5 [==============================] - 1s 189ms/step - loss: 1.4205 - accuracy: 0.5299 - val_loss: 4.2974 - val_accuracy: 0.3111
# Epoch 245/1000
# 5/5 [==============================] - 1s 206ms/step - loss: 1.4891 - accuracy: 0.4750 - val_loss: 4.0555 - val_accuracy: 0.2889
# Epoch 246/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 1.3044 - accuracy: 0.5714 - val_loss: 3.8722 - val_accuracy: 0.2889
# Epoch 247/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 1.6900 - accuracy: 0.5170 - val_loss: 3.7937 - val_accuracy: 0.3333
# Epoch 248/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 1.2748 - accuracy: 0.5688 - val_loss: 3.7587 - val_accuracy: 0.3333
# Epoch 249/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.6086 - accuracy: 0.5170 - val_loss: 4.2166 - val_accuracy: 0.3778
# Epoch 250/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.3975 - accuracy: 0.5102 - val_loss: 4.3771 - val_accuracy: 0.3556
# Epoch 251/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.4981 - accuracy: 0.5306 - val_loss: 4.0636 - val_accuracy: 0.3333
# Epoch 252/1000
# 5/5 [==============================] - 1s 202ms/step - loss: 1.3068 - accuracy: 0.5374 - val_loss: 3.9894 - val_accuracy: 0.2889
# Epoch 253/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 1.2350 - accuracy: 0.5646 - val_loss: 4.0935 - val_accuracy: 0.3111
# Epoch 254/1000
# 5/5 [==============================] - 1s 215ms/step - loss: 1.4405 - accuracy: 0.5688 - val_loss: 4.2831 - val_accuracy: 0.2889
# Epoch 255/1000
# 5/5 [==============================] - 1s 183ms/step - loss: 1.2110 - accuracy: 0.6269 - val_loss: 4.2408 - val_accuracy: 0.3111
# Epoch 256/1000
# 5/5 [==============================] - 1s 201ms/step - loss: 1.3236 - accuracy: 0.5646 - val_loss: 4.0422 - val_accuracy: 0.3333
# Epoch 257/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 1.3732 - accuracy: 0.5312 - val_loss: 4.0980 - val_accuracy: 0.3111
# Epoch 258/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.2382 - accuracy: 0.5646 - val_loss: 4.5752 - val_accuracy: 0.2667
# Epoch 259/1000
# 5/5 [==============================] - 1s 184ms/step - loss: 1.0678 - accuracy: 0.6871 - val_loss: 4.8367 - val_accuracy: 0.2667
# Epoch 260/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.2745 - accuracy: 0.5850 - val_loss: 4.6868 - val_accuracy: 0.2889
# Epoch 261/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 1.2631 - accuracy: 0.5646 - val_loss: 4.5346 - val_accuracy: 0.3556
# Epoch 262/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 1.1639 - accuracy: 0.6062 - val_loss: 4.3857 - val_accuracy: 0.4000
# Epoch 263/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 1.2534 - accuracy: 0.5986 - val_loss: 4.6351 - val_accuracy: 0.4000
# Epoch 264/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 1.1408 - accuracy: 0.5986 - val_loss: 4.7356 - val_accuracy: 0.3333
# Epoch 265/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 1.0997 - accuracy: 0.6667 - val_loss: 4.9440 - val_accuracy: 0.3111
# Epoch 266/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 1.1348 - accuracy: 0.6375 - val_loss: 4.7682 - val_accuracy: 0.2444
# Epoch 267/1000
# 5/5 [==============================] - 1s 188ms/step - loss: 1.5593 - accuracy: 0.5224 - val_loss: 4.5305 - val_accuracy: 0.2667
# Epoch 268/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 1.2890 - accuracy: 0.5750 - val_loss: 4.4255 - val_accuracy: 0.3111
# Epoch 269/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 1.1192 - accuracy: 0.6054 - val_loss: 4.3801 - val_accuracy: 0.2444
# Epoch 270/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 1.3229 - accuracy: 0.5714 - val_loss: 4.2030 - val_accuracy: 0.2667
# Epoch 271/1000
# 5/5 [==============================] - 1s 188ms/step - loss: 1.2172 - accuracy: 0.5918 - val_loss: 4.2071 - val_accuracy: 0.3556
# Epoch 272/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 1.1622 - accuracy: 0.6054 - val_loss: 4.2626 - val_accuracy: 0.3111
# Epoch 273/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 1.2400 - accuracy: 0.5875 - val_loss: 4.7271 - val_accuracy: 0.3333
# Epoch 274/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 1.2786 - accuracy: 0.5714 - val_loss: 5.5558 - val_accuracy: 0.2222
# Epoch 275/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 1.1604 - accuracy: 0.5782 - val_loss: 5.9816 - val_accuracy: 0.1556
# Epoch 276/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.1744 - accuracy: 0.6667 - val_loss: 5.6365 - val_accuracy: 0.2222
# Epoch 277/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 1.1027 - accuracy: 0.6259 - val_loss: 5.1820 - val_accuracy: 0.2222
# Epoch 278/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.2432 - accuracy: 0.6190 - val_loss: 4.9929 - val_accuracy: 0.2000
# Epoch 279/1000
# 5/5 [==============================] - 1s 208ms/step - loss: 1.0039 - accuracy: 0.6313 - val_loss: 4.8713 - val_accuracy: 0.2222
# Epoch 280/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 1.3684 - accuracy: 0.6122 - val_loss: 5.0419 - val_accuracy: 0.1778
# Epoch 281/1000
# 5/5 [==============================] - 1s 194ms/step - loss: 1.1853 - accuracy: 0.6327 - val_loss: 5.4649 - val_accuracy: 0.2222
# Epoch 282/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 1.1911 - accuracy: 0.5714 - val_loss: 5.0879 - val_accuracy: 0.2667
# Epoch 283/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 1.1979 - accuracy: 0.5986 - val_loss: 4.9509 - val_accuracy: 0.3111
# Epoch 284/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.1890 - accuracy: 0.5918 - val_loss: 4.9710 - val_accuracy: 0.2444
# Epoch 285/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.3862 - accuracy: 0.5646 - val_loss: 4.2889 - val_accuracy: 0.3111
# Epoch 286/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 1.1621 - accuracy: 0.6313 - val_loss: 3.9531 - val_accuracy: 0.2889
# Epoch 287/1000
# 5/5 [==============================] - 1s 189ms/step - loss: 1.1046 - accuracy: 0.6343 - val_loss: 3.9623 - val_accuracy: 0.3333
# Epoch 288/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 1.2165 - accuracy: 0.5813 - val_loss: 3.9718 - val_accuracy: 0.3778
# Epoch 289/1000
# 5/5 [==============================] - 1s 191ms/step - loss: 1.0683 - accuracy: 0.6122 - val_loss: 3.8453 - val_accuracy: 0.3556
# Epoch 290/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 0.9902 - accuracy: 0.6395 - val_loss: 4.0186 - val_accuracy: 0.3111
# Epoch 291/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 1.1939 - accuracy: 0.6000 - val_loss: 4.2983 - val_accuracy: 0.3111
# Epoch 292/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.1100 - accuracy: 0.6463 - val_loss: 4.3638 - val_accuracy: 0.2889
# Epoch 293/1000
# 5/5 [==============================] - 1s 186ms/step - loss: 1.2228 - accuracy: 0.5821 - val_loss: 4.2369 - val_accuracy: 0.3556
# Epoch 294/1000
# 5/5 [==============================] - 1s 208ms/step - loss: 1.0003 - accuracy: 0.6375 - val_loss: 4.0894 - val_accuracy: 0.3333
# Epoch 295/1000
# 5/5 [==============================] - 1s 189ms/step - loss: 1.1004 - accuracy: 0.6327 - val_loss: 4.1509 - val_accuracy: 0.3111
# Epoch 296/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.0732 - accuracy: 0.6463 - val_loss: 4.2782 - val_accuracy: 0.3556
# Epoch 297/1000
# 5/5 [==============================] - 1s 203ms/step - loss: 1.4347 - accuracy: 0.5034 - val_loss: 4.2289 - val_accuracy: 0.3556
# Epoch 298/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 1.1012 - accuracy: 0.6313 - val_loss: 4.2172 - val_accuracy: 0.3556
# Epoch 299/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 1.1568 - accuracy: 0.6327 - val_loss: 4.1670 - val_accuracy: 0.2889
# Epoch 300/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.2291 - accuracy: 0.5646 - val_loss: 4.0834 - val_accuracy: 0.3333
# Epoch 301/1000
# 5/5 [==============================] - 1s 189ms/step - loss: 0.9751 - accuracy: 0.6531 - val_loss: 4.1588 - val_accuracy: 0.2889
# Epoch 302/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 1.1518 - accuracy: 0.6125 - val_loss: 4.5684 - val_accuracy: 0.3111
# Epoch 303/1000
# 5/5 [==============================] - 1s 200ms/step - loss: 1.1406 - accuracy: 0.6122 - val_loss: 4.6892 - val_accuracy: 0.2667
# Epoch 304/1000
# 5/5 [==============================] - 1s 183ms/step - loss: 0.9654 - accuracy: 0.6716 - val_loss: 4.8561 - val_accuracy: 0.2222
# Epoch 305/1000
# 5/5 [==============================] - 1s 217ms/step - loss: 1.2387 - accuracy: 0.6062 - val_loss: 4.8110 - val_accuracy: 0.3111
# Epoch 306/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 1.0084 - accuracy: 0.6531 - val_loss: 4.8507 - val_accuracy: 0.3333
# Epoch 307/1000
# 5/5 [==============================] - 1s 190ms/step - loss: 1.0924 - accuracy: 0.6259 - val_loss: 4.6431 - val_accuracy: 0.3333
# Epoch 308/1000
# 5/5 [==============================] - 1s 200ms/step - loss: 1.0098 - accuracy: 0.6463 - val_loss: 4.3921 - val_accuracy: 0.3556
# Epoch 309/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.1493 - accuracy: 0.5986 - val_loss: 4.3366 - val_accuracy: 0.3556
# Epoch 310/1000
# 5/5 [==============================] - 1s 202ms/step - loss: 1.2621 - accuracy: 0.5646 - val_loss: 4.4041 - val_accuracy: 0.3556
# Epoch 311/1000
# 5/5 [==============================] - 1s 215ms/step - loss: 1.1105 - accuracy: 0.6500 - val_loss: 4.4219 - val_accuracy: 0.3333
# Epoch 312/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 1.0261 - accuracy: 0.6327 - val_loss: 4.3665 - val_accuracy: 0.3111
# Epoch 313/1000
# 5/5 [==============================] - 1s 191ms/step - loss: 0.9653 - accuracy: 0.6735 - val_loss: 4.4371 - val_accuracy: 0.3556
# Epoch 314/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 1.2464 - accuracy: 0.5918 - val_loss: 4.3124 - val_accuracy: 0.3556
# Epoch 315/1000
# 5/5 [==============================] - 1s 205ms/step - loss: 1.1088 - accuracy: 0.6190 - val_loss: 4.4465 - val_accuracy: 0.2444
# Epoch 316/1000
# 5/5 [==============================] - 1s 203ms/step - loss: 1.1129 - accuracy: 0.6190 - val_loss: 4.7015 - val_accuracy: 0.2667
# Epoch 317/1000
# 5/5 [==============================] - 1s 215ms/step - loss: 0.9952 - accuracy: 0.7125 - val_loss: 4.7739 - val_accuracy: 0.2889
# Epoch 318/1000
# 5/5 [==============================] - 1s 200ms/step - loss: 1.0428 - accuracy: 0.6463 - val_loss: 4.9106 - val_accuracy: 0.3111
# Epoch 319/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 1.1554 - accuracy: 0.6463 - val_loss: 5.0392 - val_accuracy: 0.2889
# Epoch 320/1000
# 5/5 [==============================] - 1s 208ms/step - loss: 0.9727 - accuracy: 0.6375 - val_loss: 5.0438 - val_accuracy: 0.2444
# Epoch 321/1000
# 5/5 [==============================] - 1s 182ms/step - loss: 1.1498 - accuracy: 0.6716 - val_loss: 4.6009 - val_accuracy: 0.2222
# Epoch 322/1000
# 5/5 [==============================] - 1s 201ms/step - loss: 0.9841 - accuracy: 0.6667 - val_loss: 4.6029 - val_accuracy: 0.2222
# Epoch 323/1000
# 5/5 [==============================] - 1s 216ms/step - loss: 1.1530 - accuracy: 0.6625 - val_loss: 4.8005 - val_accuracy: 0.2222
# Epoch 324/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 0.9899 - accuracy: 0.6803 - val_loss: 4.8652 - val_accuracy: 0.2222
# Epoch 325/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 0.9285 - accuracy: 0.6939 - val_loss: 5.5215 - val_accuracy: 0.1333
# Epoch 326/1000
# 5/5 [==============================] - 1s 215ms/step - loss: 0.9848 - accuracy: 0.6812 - val_loss: 5.7590 - val_accuracy: 0.1556
# Epoch 327/1000
# 5/5 [==============================] - 1s 187ms/step - loss: 0.8284 - accuracy: 0.7313 - val_loss: 5.4240 - val_accuracy: 0.1556
# Epoch 328/1000
# 5/5 [==============================] - 1s 216ms/step - loss: 1.0580 - accuracy: 0.6625 - val_loss: 5.3081 - val_accuracy: 0.1333
# Epoch 329/1000
# ...
# Epoch 890/1000
# 5/5 [==============================] - 1s 228ms/step - loss: 0.4268 - accuracy: 0.8250 - val_loss: 4.8785 - val_accuracy: 0.3778
# Epoch 891/1000
# 5/5 [==============================] - 1s 203ms/step - loss: 0.3649 - accuracy: 0.8881 - val_loss: 4.9788 - val_accuracy: 0.3333
# Epoch 892/1000
# 5/5 [==============================] - 1s 215ms/step - loss: 0.2540 - accuracy: 0.9184 - val_loss: 5.0158 - val_accuracy: 0.3556
# Epoch 893/1000
# 5/5 [==============================] - 1s 226ms/step - loss: 0.3704 - accuracy: 0.8938 - val_loss: 4.7146 - val_accuracy: 0.3333
# Epoch 894/1000
# 5/5 [==============================] - 1s 217ms/step - loss: 0.2946 - accuracy: 0.9048 - val_loss: 4.5757 - val_accuracy: 0.3556
# Epoch 895/1000
# 5/5 [==============================] - 1s 221ms/step - loss: 0.4071 - accuracy: 0.8813 - val_loss: 4.4827 - val_accuracy: 0.3778
# Epoch 896/1000
# 5/5 [==============================] - 1s 206ms/step - loss: 0.3409 - accuracy: 0.8844 - val_loss: 4.6344 - val_accuracy: 0.3333
# Epoch 897/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 0.4265 - accuracy: 0.8582 - val_loss: 5.2038 - val_accuracy: 0.3111
# Epoch 898/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 0.2300 - accuracy: 0.9320 - val_loss: 5.5286 - val_accuracy: 0.3111
# Epoch 899/1000
# 5/5 [==============================] - 1s 226ms/step - loss: 0.4526 - accuracy: 0.8813 - val_loss: 5.5974 - val_accuracy: 0.3111
# Epoch 900/1000
# 5/5 [==============================] - 1s 206ms/step - loss: 0.2894 - accuracy: 0.9252 - val_loss: 5.5110 - val_accuracy: 0.2667
# Epoch 901/1000
# 5/5 [==============================] - 1s 206ms/step - loss: 0.3651 - accuracy: 0.8844 - val_loss: 5.3455 - val_accuracy: 0.2889
# Epoch 902/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 0.2882 - accuracy: 0.9116 - val_loss: 5.0991 - val_accuracy: 0.2889
# Epoch 903/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 0.3897 - accuracy: 0.8912 - val_loss: 5.0024 - val_accuracy: 0.3111
# Epoch 904/1000
# 5/5 [==============================] - 1s 229ms/step - loss: 0.3816 - accuracy: 0.8813 - val_loss: 4.9652 - val_accuracy: 0.3111
# Epoch 905/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 0.3601 - accuracy: 0.8571 - val_loss: 4.9638 - val_accuracy: 0.3111
# Epoch 906/1000
# 5/5 [==============================] - 1s 213ms/step - loss: 0.1860 - accuracy: 0.9388 - val_loss: 4.9036 - val_accuracy: 0.3111
# Epoch 907/1000
# 5/5 [==============================] - 1s 204ms/step - loss: 0.3633 - accuracy: 0.8776 - val_loss: 4.7441 - val_accuracy: 0.4000
# Epoch 908/1000
# 5/5 [==============================] - 1s 227ms/step - loss: 0.3877 - accuracy: 0.9000 - val_loss: 4.7254 - val_accuracy: 0.4000
# Epoch 909/1000
# 5/5 [==============================] - 1s 216ms/step - loss: 0.2567 - accuracy: 0.8776 - val_loss: 4.9344 - val_accuracy: 0.4222
# Epoch 910/1000
# 5/5 [==============================] - 1s 199ms/step - loss: 0.3077 - accuracy: 0.8806 - val_loss: 5.0025 - val_accuracy: 0.3556
# Epoch 911/1000
# 5/5 [==============================] - 1s 221ms/step - loss: 0.3753 - accuracy: 0.8844 - val_loss: 5.2165 - val_accuracy: 0.2889
# Epoch 912/1000
# 5/5 [==============================] - 1s 222ms/step - loss: 0.3210 - accuracy: 0.8750 - val_loss: 4.9377 - val_accuracy: 0.3556
# Epoch 913/1000
# 5/5 [==============================] - 1s 196ms/step - loss: 0.2164 - accuracy: 0.9252 - val_loss: 4.8326 - val_accuracy: 0.3778
# Epoch 914/1000
# 5/5 [==============================] - 1s 229ms/step - loss: 0.3946 - accuracy: 0.9000 - val_loss: 4.9878 - val_accuracy: 0.3778
# Epoch 915/1000
# 5/5 [==============================] - 1s 206ms/step - loss: 0.2764 - accuracy: 0.9048 - val_loss: 5.0381 - val_accuracy: 0.3778
# Epoch 916/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 0.2515 - accuracy: 0.8980 - val_loss: 5.0896 - val_accuracy: 0.3556
# Epoch 917/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 0.2250 - accuracy: 0.9030 - val_loss: 5.3016 - val_accuracy: 0.3111
# Epoch 918/1000
# 5/5 [==============================] - 1s 222ms/step - loss: 0.2569 - accuracy: 0.9312 - val_loss: 5.4851 - val_accuracy: 0.3111
# Epoch 919/1000
# 5/5 [==============================] - 1s 200ms/step - loss: 0.2001 - accuracy: 0.9320 - val_loss: 5.6257 - val_accuracy: 0.3111
# Epoch 920/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 0.2477 - accuracy: 0.9252 - val_loss: 5.5757 - val_accuracy: 0.3333
# Epoch 921/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 0.3278 - accuracy: 0.8912 - val_loss: 5.5447 - val_accuracy: 0.3111
# Epoch 922/1000
# 5/5 [==============================] - 1s 225ms/step - loss: 0.2869 - accuracy: 0.9000 - val_loss: 5.7008 - val_accuracy: 0.3333
# Epoch 923/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 0.4196 - accuracy: 0.8571 - val_loss: 5.8533 - val_accuracy: 0.3111
# Epoch 924/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 0.3592 - accuracy: 0.9048 - val_loss: 5.9613 - val_accuracy: 0.2667
# Epoch 925/1000
# 5/5 [==============================] - 1s 201ms/step - loss: 0.2155 - accuracy: 0.9320 - val_loss: 6.1182 - val_accuracy: 0.2667
# Epoch 926/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 0.3031 - accuracy: 0.8980 - val_loss: 5.9872 - val_accuracy: 0.2667
# Epoch 927/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 0.2754 - accuracy: 0.8980 - val_loss: 6.1402 - val_accuracy: 0.2667
# Epoch 928/1000
# 5/5 [==============================] - 1s 228ms/step - loss: 0.2078 - accuracy: 0.9375 - val_loss: 6.0202 - val_accuracy: 0.2222
# Epoch 929/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 0.3583 - accuracy: 0.8776 - val_loss: 6.1466 - val_accuracy: 0.2000
# Epoch 930/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 0.4366 - accuracy: 0.8707 - val_loss: 6.3428 - val_accuracy: 0.1778
# Epoch 931/1000
# 5/5 [==============================] - 1s 197ms/step - loss: 0.3786 - accuracy: 0.9048 - val_loss: 6.1872 - val_accuracy: 0.2222
# Epoch 932/1000
# 5/5 [==============================] - 1s 213ms/step - loss: 0.3007 - accuracy: 0.8639 - val_loss: 5.9163 - val_accuracy: 0.2667
# Epoch 933/1000
# 5/5 [==============================] - 1s 215ms/step - loss: 0.3469 - accuracy: 0.8844 - val_loss: 5.9079 - val_accuracy: 0.2222
# Epoch 934/1000
# 5/5 [==============================] - 1s 224ms/step - loss: 0.4070 - accuracy: 0.8687 - val_loss: 5.8600 - val_accuracy: 0.1778
# Epoch 935/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 0.2989 - accuracy: 0.9048 - val_loss: 5.9077 - val_accuracy: 0.2444
# Epoch 936/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 0.2419 - accuracy: 0.8980 - val_loss: 6.7844 - val_accuracy: 0.2222
# Epoch 937/1000
# 5/5 [==============================] - 1s 204ms/step - loss: 0.5414 - accuracy: 0.8163 - val_loss: 5.5228 - val_accuracy: 0.2222
# Epoch 938/1000
# 5/5 [==============================] - 1s 225ms/step - loss: 0.3346 - accuracy: 0.8938 - val_loss: 4.7705 - val_accuracy: 0.3333
# Epoch 939/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 0.2268 - accuracy: 0.9116 - val_loss: 4.5947 - val_accuracy: 0.3556
# Epoch 940/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 0.4172 - accuracy: 0.8731 - val_loss: 4.5320 - val_accuracy: 0.4000
# Epoch 941/1000
# 5/5 [==============================] - 1s 222ms/step - loss: 0.2080 - accuracy: 0.9500 - val_loss: 4.6389 - val_accuracy: 0.4222
# Epoch 942/1000
# 5/5 [==============================] - 1s 208ms/step - loss: 0.2918 - accuracy: 0.8980 - val_loss: 4.6480 - val_accuracy: 0.4222
# Epoch 943/1000
# 5/5 [==============================] - 1s 216ms/step - loss: 0.3265 - accuracy: 0.8875 - val_loss: 4.6428 - val_accuracy: 0.4667
# Epoch 944/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 0.2985 - accuracy: 0.9030 - val_loss: 4.6866 - val_accuracy: 0.4444
# Epoch 945/1000
# 5/5 [==============================] - 1s 223ms/step - loss: 0.2280 - accuracy: 0.9125 - val_loss: 4.8367 - val_accuracy: 0.4444
# Epoch 946/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 0.3309 - accuracy: 0.9116 - val_loss: 5.1004 - val_accuracy: 0.4222
# Epoch 947/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 0.2609 - accuracy: 0.9116 - val_loss: 5.5542 - val_accuracy: 0.3556
# Epoch 948/1000
# 5/5 [==============================] - 1s 221ms/step - loss: 0.2722 - accuracy: 0.8912 - val_loss: 5.6722 - val_accuracy: 0.3111
# Epoch 949/1000
# 5/5 [==============================] - 1s 216ms/step - loss: 0.2827 - accuracy: 0.8980 - val_loss: 5.5340 - val_accuracy: 0.3333
# Epoch 950/1000
# 5/5 [==============================] - 1s 219ms/step - loss: 0.2378 - accuracy: 0.9184 - val_loss: 5.5020 - val_accuracy: 0.3778
# Epoch 951/1000
# 5/5 [==============================] - 1s 216ms/step - loss: 0.3280 - accuracy: 0.8639 - val_loss: 5.4564 - val_accuracy: 0.3333
# Epoch 952/1000
# 5/5 [==============================] - 1s 221ms/step - loss: 0.3682 - accuracy: 0.9000 - val_loss: 5.2402 - val_accuracy: 0.2889
# Epoch 953/1000
# 5/5 [==============================] - 1s 215ms/step - loss: 0.3501 - accuracy: 0.8707 - val_loss: 5.1724 - val_accuracy: 0.3111
# Epoch 954/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 0.2855 - accuracy: 0.9048 - val_loss: 5.1258 - val_accuracy: 0.3111
# Epoch 955/1000
# 5/5 [==============================] - 1s 216ms/step - loss: 0.2881 - accuracy: 0.8938 - val_loss: 5.1257 - val_accuracy: 0.3333
# Epoch 956/1000
# 5/5 [==============================] - 1s 193ms/step - loss: 0.3197 - accuracy: 0.8955 - val_loss: 4.9908 - val_accuracy: 0.3556
# Epoch 957/1000
# 5/5 [==============================] - 1s 226ms/step - loss: 0.2896 - accuracy: 0.9062 - val_loss: 4.9362 - val_accuracy: 0.3556
# Epoch 958/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 0.3340 - accuracy: 0.8912 - val_loss: 5.0834 - val_accuracy: 0.3778
# Epoch 959/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 0.3107 - accuracy: 0.8844 - val_loss: 5.4503 - val_accuracy: 0.3778
# Epoch 960/1000
# 5/5 [==============================] - 1s 221ms/step - loss: 0.4029 - accuracy: 0.8844 - val_loss: 6.0882 - val_accuracy: 0.3111
# Epoch 961/1000
# 5/5 [==============================] - 1s 213ms/step - loss: 0.4220 - accuracy: 0.8750 - val_loss: 6.7166 - val_accuracy: 0.2889
# Epoch 962/1000
# 5/5 [==============================] - 1s 201ms/step - loss: 0.6971 - accuracy: 0.8433 - val_loss: 6.8199 - val_accuracy: 0.2444
# Epoch 963/1000
# 5/5 [==============================] - 1s 212ms/step - loss: 0.3424 - accuracy: 0.8844 - val_loss: 6.5718 - val_accuracy: 0.2222
# Epoch 964/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 0.4114 - accuracy: 0.8639 - val_loss: 6.5845 - val_accuracy: 0.2444
# Epoch 965/1000
# 5/5 [==============================] - 1s 219ms/step - loss: 0.4242 - accuracy: 0.8687 - val_loss: 6.1584 - val_accuracy: 0.2889
# Epoch 966/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 0.3102 - accuracy: 0.8912 - val_loss: 5.7466 - val_accuracy: 0.2667
# Epoch 967/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 0.3798 - accuracy: 0.9048 - val_loss: 5.5552 - val_accuracy: 0.2889
# Epoch 968/1000
# 5/5 [==============================] - 1s 223ms/step - loss: 0.3818 - accuracy: 0.8438 - val_loss: 5.3212 - val_accuracy: 0.3333
# Epoch 969/1000
# 5/5 [==============================] - 1s 209ms/step - loss: 0.4214 - accuracy: 0.8571 - val_loss: 5.2494 - val_accuracy: 0.3556
# Epoch 970/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 0.2922 - accuracy: 0.9048 - val_loss: 5.1973 - val_accuracy: 0.3556
# Epoch 971/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 0.3015 - accuracy: 0.9116 - val_loss: 5.2177 - val_accuracy: 0.3556
# Epoch 972/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 0.2844 - accuracy: 0.9116 - val_loss: 5.1227 - val_accuracy: 0.3556
# Epoch 973/1000
# 5/5 [==============================] - 1s 195ms/step - loss: 0.2196 - accuracy: 0.9116 - val_loss: 5.0965 - val_accuracy: 0.3556
# Epoch 974/1000
# 5/5 [==============================] - 1s 216ms/step - loss: 0.2608 - accuracy: 0.8980 - val_loss: 5.0654 - val_accuracy: 0.3333
# Epoch 975/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 0.2711 - accuracy: 0.9048 - val_loss: 5.0484 - val_accuracy: 0.3556
# Epoch 976/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 0.3522 - accuracy: 0.9048 - val_loss: 5.2908 - val_accuracy: 0.3556
# Epoch 977/1000
# 5/5 [==============================] - 1s 226ms/step - loss: 0.2910 - accuracy: 0.9250 - val_loss: 5.6903 - val_accuracy: 0.3778
# Epoch 978/1000
# 5/5 [==============================] - 1s 211ms/step - loss: 0.3261 - accuracy: 0.9252 - val_loss: 5.9891 - val_accuracy: 0.3111
# Epoch 979/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 0.2770 - accuracy: 0.9320 - val_loss: 6.2294 - val_accuracy: 0.2444
# Epoch 980/1000
# 5/5 [==============================] - 1s 228ms/step - loss: 0.3752 - accuracy: 0.8938 - val_loss: 5.9122 - val_accuracy: 0.2667
# Epoch 981/1000
# 5/5 [==============================] - 1s 201ms/step - loss: 0.2233 - accuracy: 0.9403 - val_loss: 5.8129 - val_accuracy: 0.2667
# Epoch 982/1000
# 5/5 [==============================] - 1s 226ms/step - loss: 0.3438 - accuracy: 0.8813 - val_loss: 5.6524 - val_accuracy: 0.2667
# Epoch 983/1000
# 5/5 [==============================] - 1s 210ms/step - loss: 0.4750 - accuracy: 0.8571 - val_loss: 5.0614 - val_accuracy: 0.3111
# Epoch 984/1000
# 5/5 [==============================] - 1s 207ms/step - loss: 0.2846 - accuracy: 0.9048 - val_loss: 4.9251 - val_accuracy: 0.3333
# Epoch 985/1000
# 5/5 [==============================] - 1s 218ms/step - loss: 0.3277 - accuracy: 0.9062 - val_loss: 5.2120 - val_accuracy: 0.3333
# Epoch 986/1000
# 5/5 [==============================] - 1s 198ms/step - loss: 0.3014 - accuracy: 0.8806 - val_loss: 5.4962 - val_accuracy: 0.3556
# Epoch 987/1000
# 5/5 [==============================] - 1s 229ms/step - loss: 0.2452 - accuracy: 0.9000 - val_loss: 5.6359 - val_accuracy: 0.3333
# Epoch 988/1000
# 5/5 [==============================] - 1s 215ms/step - loss: 0.3133 - accuracy: 0.8844 - val_loss: 5.7520 - val_accuracy: 0.3333
# Epoch 989/1000
# 5/5 [==============================] - 1s 219ms/step - loss: 0.3351 - accuracy: 0.8776 - val_loss: 5.8230 - val_accuracy: 0.3333
# Epoch 990/1000
# 5/5 [==============================] - 1s 222ms/step - loss: 0.3291 - accuracy: 0.8980 - val_loss: 5.8254 - val_accuracy: 0.3111
# Epoch 991/1000
# 5/5 [==============================] - 1s 204ms/step - loss: 0.2752 - accuracy: 0.9320 - val_loss: 5.8926 - val_accuracy: 0.2889
# Epoch 992/1000
# 5/5 [==============================] - 1s 226ms/step - loss: 0.2123 - accuracy: 0.9250 - val_loss: 6.0819 - val_accuracy: 0.2667
# Epoch 993/1000
# 5/5 [==============================] - 1s 215ms/step - loss: 0.4091 - accuracy: 0.9048 - val_loss: 6.2257 - val_accuracy: 0.2889
# Epoch 994/1000
# 5/5 [==============================] - 1s 218ms/step - loss: 0.2891 - accuracy: 0.8980 - val_loss: 6.2284 - val_accuracy: 0.2222
# Epoch 995/1000
# 5/5 [==============================] - 1s 222ms/step - loss: 0.2850 - accuracy: 0.8980 - val_loss: 5.9612 - val_accuracy: 0.2222
# Epoch 996/1000
# 5/5 [==============================] - 1s 217ms/step - loss: 0.2306 - accuracy: 0.9048 - val_loss: 5.8874 - val_accuracy: 0.1778
# Epoch 997/1000
# 5/5 [==============================] - 1s 214ms/step - loss: 0.4217 - accuracy: 0.8844 - val_loss: 5.7453 - val_accuracy: 0.2222
# Epoch 998/1000
# 5/5 [==============================] - 1s 217ms/step - loss: 0.2423 - accuracy: 0.9320 - val_loss: 5.6683 - val_accuracy: 0.2444
# Epoch 999/1000
# 5/5 [==============================] - 1s 241ms/step - loss: 0.2353 - accuracy: 0.9125 - val_loss: 5.5800 - val_accuracy: 0.2222
# Epoch 1000/1000
# 5/5 [==============================] - 1s 222ms/step - loss: 0.5114 - accuracy: 0.8571 - val_loss: 5.7860 - val_accuracy: 0.2667

# %%
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading https://files.pythonhosted.org/packages/bb/7a/fd8059a3881d3ab37ac8f72f56b73937a14e8bb14a9733e68cc8b17dbe3c/bayesian-optimization-1.2.0.tar.gz
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.19.5)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.0.0)
# Building wheels for collected packages: bayesian-optimization
#   Building wheel for bayesian-optimization (setup.py) ... done
#   Created wheel for bayesian-optimization: filename=bayesian_optimization-1.2.0-cp36-none-any.whl size=11685 sha256=4a7c173a54a48027a9afea549b0dc87afcd1ab8de6c1a25e8fcd8a8d46ac85b5
#   Stored in directory: /root/.cache/pip/wheels/5a/56/ae/e0e3c1fc1954dc3ec712e2df547235ed072b448094d8f94aec
# Successfully built bayesian-optimization
# Installing collected packages: bayesian-optimization
# Successfully installed bayesian-optimization-1.2.0

# %%
pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.11.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.41.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading https://files.pythonhosted.org/packages/8b/03/be33e89f55866065a02e515c5b319304a801a9f1027a9b311a9b1d1f8dc7/scikit_optimize-0.8.1-py2.py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 3.6MB/s
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (0.22.2.post1)
# Collecting pyaml>=16.9
#   Downloading https://files.pythonhosted.org/packages/15/c4/1310a054d33abc318426a956e7d6df0df76a6ddfa9c66f6310274fb75d42/pyaml-20.4.0-py2.py3-none-any.whl
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (1.0.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (1.19.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (1.4.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from pyaml>=16.9->scikit-optimize) (3.13)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-20.4.0 scikit-optimize-0.8.1

# %%
# import packages
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import cross_val_score 
from sklearn.preprocessing import StandardScaler
from skopt.searchcv import BayesSearchCV
from skopt.space import Integer, Real, Categorical 
from skopt.utils import use_named_args
from skopt import gp_minimize

import warnings

warnings.filterwarnings("ignore")

# %%
# define search space 
params = {
    "n_estimators": [100, 200, 300, 400],
    "max_depth": (1, 9),
    "criterion": ["gini", "entropy"],
}

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.models import load_model
rf_classifier = Sequential()
search = BayesSearchCV(
    estimator=rf_classifier,
    search_spaces=params,
    n_jobs=1,
    cv=5,
    n_iter=30,
    scoring="accuracy",
    verbose=4,
    random_state=42
)

# %%
x_train,x_test,y_train,y_test=sklearn.model_selection.train_test_split(X,Y,test_size)
search.fit(x_train,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-e96b9a2f501d> in <module>()
# ----> 1 x_train,x_test,y_train,y_test=sklearn.model_selection.train_test_split(X,Y,test_size)
#       2 search.fit(x_train,y_test)
#
# NameError: name 'sklearn' is not defined

# %%
# report the best result

print(search.best_score_)
print(search.best_params_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-121-418627be84d2> in <module>()
#       1 # report the best result
#       2
# ----> 3 print(search.best_score_)
#       4 print(search.best_params_)
#
# /usr/local/lib/python3.6/dist-packages/skopt/searchcv.py in best_score_(self)
#     370     def best_score_(self):
#     371         check_is_fitted(self, 'cv_results_')
# --> 372         return self.cv_results_['mean_test_score'][self.best_index_]
#     373
#     374     # copied for compatibility with 0.19 sklearn from 0.18 BaseSearchCV
#
# TypeError: list indices must be integers or slices, not NoneType
